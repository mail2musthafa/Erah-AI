# %% [markdown]
# # 08 — Multi-Head Attention & Transformer Mechanics
# Erah AI Phase 01: Scaled dot-product attention and causal masking.

# %%
from erah_ai.foundations.attention import MultiHeadAttention
import numpy as np

mha = MultiHeadAttention(d_model=16, num_heads=2)
x = np.random.randn(1, 4, 16)
out, weights = mha.forward(x, causal=True)
print("Output shape:", out.shape)
print("Attention weights head 0:\n", np.round(weights[0, 0], 3))
