# %% [markdown]
# # 02 — Pandas Data Lab & Evaluation Datasets
# Erah AI Phase 01: Cleaning, profiling, and analyzing multilingual test cases.

# %%
import pandas as pd

df = pd.DataFrame([
    {"question": "How to refund?", "lang": "en", "intent": "billing"},
    {"question": "Wie erhalte ich eine Rückerstattung?", "lang": "de", "intent": "billing"},
    {"question": "API 500 error", "lang": "en", "intent": "tech"}
])
print(df.head())
print("\nIntent breakdown:", df["intent"].value_counts())
