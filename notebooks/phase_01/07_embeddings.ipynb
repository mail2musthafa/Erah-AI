# %% [markdown]
# # 07 — Embeddings & Vector Similarity
# Erah AI Phase 01: Cosine similarity and in-memory semantic search.

# %%
from erah_ai.foundations.embeddings import SemanticSearchEngine

engine = SemanticSearchEngine()
engine.add_document("d1", "Invoice billing refund")
engine.add_document("d2", "System crash 500 error")

print(engine.search("Need refund"))
