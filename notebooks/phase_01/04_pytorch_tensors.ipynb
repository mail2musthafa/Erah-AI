# %% [markdown]
# # 04 — Tensor Mechanics
# Erah AI Phase 01: Understanding tensor dimensions, shapes, and devices.

# %%
import numpy as np

# Batch of token vectors (batch=2, seq_len=3, d_model=4)
x = np.random.randn(2, 3, 4)
print("Tensor shape:", x.shape)
print("Mean across embedding dimension:", np.mean(x, axis=-1))
